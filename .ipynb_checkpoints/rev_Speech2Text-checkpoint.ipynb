# %%
import requests
import json
import time
import pandas as pd
import os

# %%
API_KEY = "Bearer 01dzB5uPPHurzlH0XSAKAZKZBKzBygteZyXkzFhfhwrmDvRvD3nkL806QPxC5ucHC5ltCJCvlVckPzRd7Qtv10nrbck-Q"
HEADERS = {'Authorization': API_KEY}

# %%
def submit_job_file(file):
    url = "https://api.rev.ai/revspeech/v1beta/jobs"
    files = { 'media': (file, open(file, 'rb'), 'audio/mp3') }
    request = requests.post(url, headers=HEADERS, files=files)
    print(request.status_code)
    if request.status_code != 200:
        
        raise Exception

    response_body = request.json()
    return response_body['id']

# %%
def view_job(id=59594172):
    url = f'https://api.rev.ai/revspeech/v1beta/jobs/{id}'
    request = requests.get(url, headers=HEADERS)

    if request.status_code != 200:
        raise Exception

    response_body = request.json()
    return response_body

# %%
def get_transcript(id='59594172'):
    url = f'https://api.rev.ai/revspeech/v1beta/jobs/{id}/transcript'
    headers = HEADERS.copy()
    headers['Accept'] = 'application/vnd.rev.transcript.v1.0+json'
    request = requests.get(url, headers=headers)

    if request.status_code != 200:
        raise

    response_body = request.json()
    return response_body

# %%
def test_workflow_with_url(url):
    print ("Submitting job with URL")
    id = submit_job_url(url)
    print ("Job created")
    view_job(id)

    while True:
        job = view_job(id)
        status = job["status"]
        print (f'Checking job transcription status: { status }')
        if status == "transcribed":
            break
        if status == "failed":
            raise

        print ("Trying in another 30 seconds")
        time.sleep(30)

    return get_transcript(id)

# %%
def test_workflow_with_file(file):
    print ("Submitting job with file")
    id = submit_job_file(file)
    print ("Job created")
    view_job(id)

    while True:
        job = view_job(id)
        status = job["status"]
        print (f'Checking job transcription status: { status }')
        if status == "transcribed":
            break
        if status == "failed":
            raise

        print ("Trying in another 30 seconds")
        time.sleep(30)

    return get_transcript(id)

# %%
def main():
    out_dict = {}
    # Testing with URL
    # media_url = "https://support.rev.com/hc/en-us/article_attachments/200043975/FTC_Sample_1_-_Single.mp3"
    # test_workflow_with_url(media_url)

    # Testing with file upload
    file = "C:\Users\dcane\OneDrive\Desktop\hackharv_2018\lion.wav"
    out_dict = test_workflow_with_file(file)
    print(out_dict)

if __name__ == "__main__":
    main()
# Out:
# Submitting job with file
# 200
# Job created
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: transcribed
# {'monologues': [{'speaker': 1, 'elements': [{'type': 'text', 'value': "Let's", 'ts': 10.53, 'end_ts': 10.92, 'confidence': 0.97}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'learn', 'ts': 10.92, 'end_ts': 11.309999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'about', 'ts': 11.34, 'end_ts': 11.76, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'lions', 'ts': 11.76, 'end_ts': 12.51, 'confidence': 0.96}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'often', 'ts': 14.84, 'end_ts': 15.229999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'called', 'ts': 15.229999999999999, 'end_ts': 15.62, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 15.62, 'end_ts': 15.739999999999998, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'king', 'ts': 15.739999999999998, 'end_ts': 15.979999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'of', 'ts': 15.979999999999999, 'end_ts': 16.07, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'beasts', 'ts': 16.07, 'end_ts': 16.64, 'confidence': 1.0}, {'type': 'punct', 'value': '. '}, {'type': 'text', 'value': 'Lions', 'ts': 17.0, 'end_ts': 17.45, 'confidence': 0.95}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'are', 'ts': 17.45, 'end_ts': 17.57, 'confidence': 0.93}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'unique', 'ts': 17.57, 'end_ts': 17.96, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'among', 'ts': 17.96, 'end_ts': 18.2, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 18.2, 'end_ts': 18.29, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'species', 'ts': 18.29, 'end_ts': 18.77, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'of', 'ts': 18.77, 'end_ts': 18.86, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 18.86, 'end_ts': 18.95, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'cat', 'ts': 18.95, 'end_ts': 19.25, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'family', 'ts': 19.25, 'end_ts': 19.7, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'for', 'ts': 19.7, 'end_ts': 19.88, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'more', 'ts': 19.88, 'end_ts': 20.15, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'than', 'ts': 20.15, 'end_ts': 20.33, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'one', 'ts': 20.33, 'end_ts': 20.509999999999998, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'reason', 'ts': 20.509999999999998, 'end_ts': 21.02, 'confidence': 1.0}, {'type': 'punct', 'value': ', '}, {'type': 'text', 'value': 'adult', 'ts': 22.89, 'end_ts': 23.31, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'male', 'ts': 23.31, 'end_ts': 23.61, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'lions', 'ts': 23.61, 'end_ts': 24.09, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'are', 'ts': 24.09, 'end_ts': 24.24, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 24.24, 'end_ts': 24.39, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'only', 'ts': 24.39, 'end_ts': 24.72, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'cats', 'ts': 24.72, 'end_ts': 25.14, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'to', 'ts': 25.14, 'end_ts': 25.259999999999998, 'confid ...

# %%
print(out_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-20b0c73b89f5> in <module>()
# ----> 1 print(out_dict)
#
# NameError: name 'out_dict' is not defined

# %%
file = "C:\Users\dcane\OneDrive\Desktop\hackharv_2018\lion.wav"
out_dict = test_workflow_with_file(file)
# Out:
#   File "<ipython-input-9-b4f85dff509d>", line 1
#     file = "C:\Users\dcane\OneDrive\Desktop\hackharv_2018\lion.wav"
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
mono = out_dict['monologues']

# %%
print(mono)
# Out:
# [{'speaker': 1, 'elements': [{'type': 'text', 'value': "Let's", 'ts': 10.53, 'end_ts': 10.92, 'confidence': 0.97}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'learn', 'ts': 10.92, 'end_ts': 11.309999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'about', 'ts': 11.34, 'end_ts': 11.76, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'lions', 'ts': 11.76, 'end_ts': 12.51, 'confidence': 0.96}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'often', 'ts': 14.84, 'end_ts': 15.229999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'called', 'ts': 15.229999999999999, 'end_ts': 15.62, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 15.62, 'end_ts': 15.739999999999998, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'king', 'ts': 15.739999999999998, 'end_ts': 15.979999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'of', 'ts': 15.979999999999999, 'end_ts': 16.07, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'beasts', 'ts': 16.07, 'end_ts': 16.64, 'confidence': 1.0}, {'type': 'punct', 'value': '. '}, {'type': 'text', 'value': 'Lions', 'ts': 17.0, 'end_ts': 17.45, 'confidence': 0.95}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'are', 'ts': 17.45, 'end_ts': 17.57, 'confidence': 0.93}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'unique', 'ts': 17.57, 'end_ts': 17.96, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'among', 'ts': 17.96, 'end_ts': 18.2, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 18.2, 'end_ts': 18.29, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'species', 'ts': 18.29, 'end_ts': 18.77, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'of', 'ts': 18.77, 'end_ts': 18.86, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 18.86, 'end_ts': 18.95, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'cat', 'ts': 18.95, 'end_ts': 19.25, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'family', 'ts': 19.25, 'end_ts': 19.7, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'for', 'ts': 19.7, 'end_ts': 19.88, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'more', 'ts': 19.88, 'end_ts': 20.15, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'than', 'ts': 20.15, 'end_ts': 20.33, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'one', 'ts': 20.33, 'end_ts': 20.509999999999998, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'reason', 'ts': 20.509999999999998, 'end_ts': 21.02, 'confidence': 1.0}, {'type': 'punct', 'value': ', '}, {'type': 'text', 'value': 'adult', 'ts': 22.89, 'end_ts': 23.31, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'male', 'ts': 23.31, 'end_ts': 23.61, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'lions', 'ts': 23.61, 'end_ts': 24.09, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'are', 'ts': 24.09, 'end_ts': 24.24, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 24.24, 'end_ts': 24.39, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'only', 'ts': 24.39, 'end_ts': 24.72, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'cats', 'ts': 24.72, 'end_ts': 25.14, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'to', 'ts': 25.14, 'end_ts': 25.259999999999998, 'confidence': 1.0}, {' ...

# %%
stuff_1 = mono[0]
print(stuff_1)
# Out:
# {'speaker': 1, 'elements': [{'type': 'text', 'value': "Let's", 'ts': 10.53, 'end_ts': 10.92, 'confidence': 0.97}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'learn', 'ts': 10.92, 'end_ts': 11.309999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'about', 'ts': 11.34, 'end_ts': 11.76, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'lions', 'ts': 11.76, 'end_ts': 12.51, 'confidence': 0.96}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'often', 'ts': 14.84, 'end_ts': 15.229999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'called', 'ts': 15.229999999999999, 'end_ts': 15.62, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 15.62, 'end_ts': 15.739999999999998, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'king', 'ts': 15.739999999999998, 'end_ts': 15.979999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'of', 'ts': 15.979999999999999, 'end_ts': 16.07, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'beasts', 'ts': 16.07, 'end_ts': 16.64, 'confidence': 1.0}, {'type': 'punct', 'value': '. '}, {'type': 'text', 'value': 'Lions', 'ts': 17.0, 'end_ts': 17.45, 'confidence': 0.95}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'are', 'ts': 17.45, 'end_ts': 17.57, 'confidence': 0.93}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'unique', 'ts': 17.57, 'end_ts': 17.96, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'among', 'ts': 17.96, 'end_ts': 18.2, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 18.2, 'end_ts': 18.29, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'species', 'ts': 18.29, 'end_ts': 18.77, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'of', 'ts': 18.77, 'end_ts': 18.86, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 18.86, 'end_ts': 18.95, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'cat', 'ts': 18.95, 'end_ts': 19.25, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'family', 'ts': 19.25, 'end_ts': 19.7, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'for', 'ts': 19.7, 'end_ts': 19.88, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'more', 'ts': 19.88, 'end_ts': 20.15, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'than', 'ts': 20.15, 'end_ts': 20.33, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'one', 'ts': 20.33, 'end_ts': 20.509999999999998, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'reason', 'ts': 20.509999999999998, 'end_ts': 21.02, 'confidence': 1.0}, {'type': 'punct', 'value': ', '}, {'type': 'text', 'value': 'adult', 'ts': 22.89, 'end_ts': 23.31, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'male', 'ts': 23.31, 'end_ts': 23.61, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'lions', 'ts': 23.61, 'end_ts': 24.09, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'are', 'ts': 24.09, 'end_ts': 24.24, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 24.24, 'end_ts': 24.39, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'only', 'ts': 24.39, 'end_ts': 24.72, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'cats', 'ts': 24.72, 'end_ts': 25.14, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'to', 'ts': 25.14, 'end_ts': 25.259999999999998, 'confidence': 1.0}, {'t ...

# %%
stuff_2 = stuff_1['elements']
print(stuff_2)
# Out:
# [{'type': 'text', 'value': "Let's", 'ts': 10.53, 'end_ts': 10.92, 'confidence': 0.97}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'learn', 'ts': 10.92, 'end_ts': 11.309999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'about', 'ts': 11.34, 'end_ts': 11.76, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'lions', 'ts': 11.76, 'end_ts': 12.51, 'confidence': 0.96}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'often', 'ts': 14.84, 'end_ts': 15.229999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'called', 'ts': 15.229999999999999, 'end_ts': 15.62, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 15.62, 'end_ts': 15.739999999999998, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'king', 'ts': 15.739999999999998, 'end_ts': 15.979999999999999, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'of', 'ts': 15.979999999999999, 'end_ts': 16.07, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'beasts', 'ts': 16.07, 'end_ts': 16.64, 'confidence': 1.0}, {'type': 'punct', 'value': '. '}, {'type': 'text', 'value': 'Lions', 'ts': 17.0, 'end_ts': 17.45, 'confidence': 0.95}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'are', 'ts': 17.45, 'end_ts': 17.57, 'confidence': 0.93}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'unique', 'ts': 17.57, 'end_ts': 17.96, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'among', 'ts': 17.96, 'end_ts': 18.2, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 18.2, 'end_ts': 18.29, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'species', 'ts': 18.29, 'end_ts': 18.77, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'of', 'ts': 18.77, 'end_ts': 18.86, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 18.86, 'end_ts': 18.95, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'cat', 'ts': 18.95, 'end_ts': 19.25, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'family', 'ts': 19.25, 'end_ts': 19.7, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'for', 'ts': 19.7, 'end_ts': 19.88, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'more', 'ts': 19.88, 'end_ts': 20.15, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'than', 'ts': 20.15, 'end_ts': 20.33, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'one', 'ts': 20.33, 'end_ts': 20.509999999999998, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'reason', 'ts': 20.509999999999998, 'end_ts': 21.02, 'confidence': 1.0}, {'type': 'punct', 'value': ', '}, {'type': 'text', 'value': 'adult', 'ts': 22.89, 'end_ts': 23.31, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'male', 'ts': 23.31, 'end_ts': 23.61, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'lions', 'ts': 23.61, 'end_ts': 24.09, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'are', 'ts': 24.09, 'end_ts': 24.24, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'the', 'ts': 24.24, 'end_ts': 24.39, 'confidence': 1.0}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'only', 'ts': 24.39, 'end_ts': 24.72, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'cats', 'ts': 24.72, 'end_ts': 25.14, 'confidence': 0.99}, {'type': 'punct', 'value': ' '}, {'type': 'text', 'value': 'to', 'ts': 25.14, 'end_ts': 25.259999999999998, 'confidence': 1.0}, {'type': 'punct', 'value': ' ' ...

# %%
stuff_3 = stuff_2[0]
print(stuff_3)
# Out:
# {'type': 'text', 'value': 'learn', 'ts': 10.92, 'end_ts': 11.309999999999999, 'confidence': 1.0}

# %%
l = []
for i in stuff_2:
    #print(i['value'])
    l.append(i['value'])
#print(l)
new_l = "".join(l)
print(new_l)
# Out:
# Let's learn about lions often called the king of beasts. Lions are unique among the species of the cat family for more than one reason, adult male lions are the only cats to have maids. In addition, lions were the only cats to live in groups. These close family groups are called pride. Lions are mammals, which means they are warm blooded, covered in for, and they feed their babies. Milk. Lions are also carnivores, which means that they eat meat. Lions are at the top of the food chain in the habitats where they live, although they are apex predators, meaning that aside from humans, no other animals prey on lions. Lions are also scavengers. They get about half of their food by scavenging, and we'll eat both animals that have died naturally and kills. They can steal from other predators like leopards, cheetahs, and hyenas. Lions will keep an eye out for circling vultures because the vultures will lead the pride to dead or dying. Animals lion prides generally have one or two adult male lions, several female lionesses and their cubs. The lionesses do almost all of the hunting, working as a team to take down, pray. Once the kill is made. However, the male lions will come in and eat first.

# %%
[stuff_3['value']]
# Out:
# ['learn']

# %%
df= pd.DataFrame({'names': [stuff_3['value']]})
print(df)
# Out:
#           names
# 0  Sean maloney

# %%
def speech_to_text(path, files):
    for file in files:
        out_dict = {}
        f_path = f'{path}{file}'
        out_dict = test_workflow_with_file(f_path)
        mono = out_dict['monologues']
        stuff_1 = mono[0]
        stuff_2 = stuff_1['elements']
        stuff_3 = stuff_2[0]
        text = stuff_3['value']
        df= pd.DataFrame({'names': [stuff_3['value']]})
        print(df)
        df.to_csv(f'{f_path}.csv')
        
        for index, col in df.iter():
   print row['c1'], row['c2']

for i in stuff_2:
    print(i['value'])

# %%
path = '/Users/piupunia/Documents/HackMIT/voice_records/'
files = os.listdir("/Users/piupunia/Documents/HackMIT/voice_records/")
files.remove('.DS_Store')
print(files)
speech_to_text(path, files)
# Out:
# ['sean_voice.mp3', 'Cynthia.mp3']
# Submitting job with file
# 200
# Job created
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: transcribed
#           names
# 0  Sean maloney
# Submitting job with file
# 200
# Job created
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: in_progress
# Trying in another 30 seconds
# Checking job transcription status: transcribed
#            names
# 0  Cynthia nixon
